# %%
import urllib2
import json

url = "https://www.googleapis.com/qpxExpress/v1/trips/search?key=AIzaSyD4_cq9cl5YtoEjR-xV73jo27MgRF_RplY"
code = {
  "request": {
    "passengers": {
      "kind": "qpxexpress#passengerCounts",
      "adultCount": 1,
    },
    "slice": [
      {
        "kind": "qpxexpress#sliceInput",
        "origin": "DCA",
        "destination": "NYC",
        "date": "2015-11-20",
      }
    ],
    "refundable": "false",
    "solutions": 5
  }
}
jsonreq = json.dumps(code, encoding = 'utf-8')
req = urllib2.Request(url, jsonreq, {'Content-Type': 'application/json'})
flight = urllib2.urlopen(req)
response = flight.read()
flight.close()
print(response)
# Out:
# {
#  "kind": "qpxExpress#tripsSearch",
#  "trips": {
#   "kind": "qpxexpress#tripOptions",
#   "requestId": "cm93555bmxa8RzTfG0MRbs",
#   "data": {
#    "kind": "qpxexpress#data",
#    "airport": [
#     {
#      "kind": "qpxexpress#airportData",
#      "code": "DCA",
#      "city": "WAS",
#      "name": "Ronald Reagan Washington Nat'l"
#     },
#     {
#      "kind": "qpxexpress#airportData",
#      "code": "EWR",
#      "city": "EWR",
#      "name": "Newark Liberty International"
#     }
#    ],
#    "city": [
#     {
#      "kind": "qpxexpress#cityData",
#      "code": "EWR",
#      "name": "Newark"
#     },
#     {
#      "kind": "qpxexpress#cityData",
#      "code": "WAS",
#      "name": "Washington"
#     }
#    ],
#    "aircraft": [
#     {
#      "kind": "qpxexpress#aircraftData",
#      "code": "ERJ",
#      "name": "Embraer ERJ-135/145"
#     }
#    ],
#    "tax": [
#     {
#      "kind": "qpxexpress#taxData",
#      "id": "ZP",
#      "name": "US Flight Segment Tax"
#     },
#     {
#      "kind": "qpxexpress#taxData",
#      "id": "XF",
#      "name": "US Passenger Facility Charge"
#     },
#     {
#      "kind": "qpxexpress#taxData",
#      "id": "US_001",
#      "name": "US Transportation Tax"
#     },
#     {
#      "kind": "qpxexpress#taxData",
#      "id": "AY_001",
#      "name": "US September 11th Security Fee"
#     }
#    ],
#    "carrier": [
#     {
#      "kind": "qpxexpress#carrierData",
#      "code": "UA",
#      "name": "United Airlines, Inc."
#     }
#    ]
#   },
#   "tripOption": [
#    {
#     "kind": "qpxexpress#tripOption",
#     "saleTotal": "USD188.10",
#     "id": "3kErYB7Ip3MOHCjsjfYkkT002",
#     "slice": [
#      {
#       "kind": "qpxexpress#sliceInfo",
#       "duration": 73,
#       "segment": [
#        {
#         "kind": "qpxexpress#segmentInfo",
#         "duration": 73,
#         "flight": {
#          "carrier": "UA",
#          "number": "4748"
#         },
#         "id": "G0pj9wKVydP-YcBu",
#         "cabin": "COACH",
#         "bookingCode": "S",
#         "bookingCodeCount": 9,
#         "marriedSegmentGroup": "0",
#         "leg": [
#          {
#           "kind": "qpxexpress#legInfo",
#           "id": "LlSZlHlYrzlYyNMz",
#           "aircraft": "ERJ",
#           "arrivalTime": "2015-11-20T22:43-05:00",
#           "departureTime": "2015-11-20T21:30-05:00",
#           "origin": "DCA",
#           "destination": "EWR",
#           "originTerminal": "B",
#           "destinationTerminal": "A",
#           "duration": 73,
#           "operatingDisclosure": "OPERATED BY EXPRESSJET AIRLINES DBA UNITED EXPRESS",
#           "onTimePerformance": 50,
#           "mileage": 198,
#           "secure": true
#          }
#         ]
#        }
#       ]
#      }
#     ],
#     "pricing": [
#      {
#       "kind": "qpxexpress#pricingInfo",
#       "fare": [
#        {
#         "kind": "qpxexpress#fareInfo",
#         "id": "AAUv/otBdsnI76pe6hMLjNTIJW163Hyn4StuCo4PteMBm9/",
#         "carrier": "UA",
#         "origin": "WAS",
#         "destination": "EWR",
#         "basisCode": "SAA21DHN"
#        }
#       ],
#       "segmentPricing": [
#        {
#         "kind": "qpxexpress#segmentPricing",
#         "fareId": "AAUv/otBdsnI76pe6hMLjNTIJW163Hyn4StuCo4PteMBm9/",
#         "segmentId": "G0pj9wKVydP-YcBu",
#         "freeBaggageOption": [
#          {
#           "kind": "qpxexpress#freeBaggageAllowance",
#           "bagDescriptor": [
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "UPTO50LB 23KG AND62LI 158LCM",
#             "count": 0,
#             "description": [
#              "Up to 50 lb/23 kg",
#              "Up to 62 li/158 lcm"
#             ],
#             "subcode": "0GO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "MUSICAL INSTRUMENTS",
#             "count": 0,
#             "subcode": "0F2"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "ARCHERY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Archery Equipment"
#             ],
#             "subcode": "0FO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "BOWLING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Bowling Equipment"
#             ],
#             "subcode": "0FS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "FISHING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Fishing Equipment"
#             ],
#             "subcode": "0D6"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "GOLF EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Golf Equipment"
#             ],
#             "subcode": "0DC"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "HOCKEY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Hockey Equipment"
#             ],
#             "subcode": "0F0"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKATEBOARD",
#             "count": 0,
#             "description": [
#              "Skateboard"
#             ],
#             "subcode": "0IS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Ski Equipment"
#             ],
#             "subcode": "0DD"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "WATER SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Water Ski Equipment"
#             ],
#             "subcode": "0G2"
#            }
#           ],
#           "pieces": 0
#          }
#         ]
#        }
#       ],
#       "baseFareTotal": "USD161.86",
#       "saleFareTotal": "USD161.86",
#       "saleTaxTotal": "USD26.24",
#       "saleTotal": "USD188.10",
#       "passengers": {
#        "kind": "qpxexpress#passengerCounts",
#        "adultCount": 1
#       },
#       "tax": [
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "US_001",
#         "chargeType": "GOVERNMENT",
#         "code": "US",
#         "country": "US",
#         "salePrice": "USD12.14"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "AY_001",
#         "chargeType": "GOVERNMENT",
#         "code": "AY",
#         "country": "US",
#         "salePrice": "USD5.60"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "XF",
#         "chargeType": "GOVERNMENT",
#         "code": "XF",
#         "country": "US",
#         "salePrice": "USD4.50"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "ZP",
#         "chargeType": "GOVERNMENT",
#         "code": "ZP",
#         "country": "US",
#         "salePrice": "USD4.00"
#        }
#       ],
#       "fareCalculation": "WAS UA EWR Q18.60 143.26SAA21DHN USD 161.86 END ZP DCA XT 12.14US 4.00ZP 5.60AY 4.50XF DCA4.50",
#       "latestTicketingTime": "2015-07-07T23:59-04:00",
#       "ptc": "ADT"
#      }
#     ]
#    },
#    {
#     "kind": "qpxexpress#tripOption",
#     "saleTotal": "USD188.10",
#     "id": "3kErYB7Ip3MOHCjsjfYkkT003",
#     "slice": [
#      {
#       "kind": "qpxexpress#sliceInfo",
#       "duration": 84,
#       "segment": [
#        {
#         "kind": "qpxexpress#segmentInfo",
#         "duration": 84,
#         "flight": {
#          "carrier": "UA",
#          "number": "5816"
#         },
#         "id": "G2EyT-DYbbEpOkuy",
#         "cabin": "COACH",
#         "bookingCode": "S",
#         "bookingCodeCount": 9,
#         "marriedSegmentGroup": "0",
#         "leg": [
#          {
#           "kind": "qpxexpress#legInfo",
#           "id": "L3Bj7ik3j7AdEdwC",
#           "aircraft": "ERJ",
#           "arrivalTime": "2015-11-20T21:44-05:00",
#           "departureTime": "2015-11-20T20:20-05:00",
#           "origin": "DCA",
#           "destination": "EWR",
#           "originTerminal": "B",
#           "destinationTerminal": "A",
#           "duration": 84,
#           "operatingDisclosure": "OPERATED BY EXPRESSJET AIRLINES DBA UNITED EXPRESS",
#           "onTimePerformance": 50,
#           "mileage": 198,
#           "secure": true
#          }
#         ]
#        }
#       ]
#      }
#     ],
#     "pricing": [
#      {
#       "kind": "qpxexpress#pricingInfo",
#       "fare": [
#        {
#         "kind": "qpxexpress#fareInfo",
#         "id": "AAUv/otBdsnI76pe6hMLjNTIJW163Hyn4StuCo4PteMBm9/",
#         "carrier": "UA",
#         "origin": "WAS",
#         "destination": "EWR",
#         "basisCode": "SAA21DHN"
#        }
#       ],
#       "segmentPricing": [
#        {
#         "kind": "qpxexpress#segmentPricing",
#         "fareId": "AAUv/otBdsnI76pe6hMLjNTIJW163Hyn4StuCo4PteMBm9/",
#         "segmentId": "G2EyT-DYbbEpOkuy",
#         "freeBaggageOption": [
#          {
#           "kind": "qpxexpress#freeBaggageAllowance",
#           "bagDescriptor": [
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "UPTO50LB 23KG AND62LI 158LCM",
#             "count": 0,
#             "description": [
#              "Up to 50 lb/23 kg",
#              "Up to 62 li/158 lcm"
#             ],
#             "subcode": "0GO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "MUSICAL INSTRUMENTS",
#             "count": 0,
#             "subcode": "0F2"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "ARCHERY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Archery Equipment"
#             ],
#             "subcode": "0FO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "BOWLING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Bowling Equipment"
#             ],
#             "subcode": "0FS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "FISHING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Fishing Equipment"
#             ],
#             "subcode": "0D6"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "GOLF EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Golf Equipment"
#             ],
#             "subcode": "0DC"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "HOCKEY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Hockey Equipment"
#             ],
#             "subcode": "0F0"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKATEBOARD",
#             "count": 0,
#             "description": [
#              "Skateboard"
#             ],
#             "subcode": "0IS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Ski Equipment"
#             ],
#             "subcode": "0DD"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "WATER SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Water Ski Equipment"
#             ],
#             "subcode": "0G2"
#            }
#           ],
#           "pieces": 0
#          }
#         ]
#        }
#       ],
#       "baseFareTotal": "USD161.86",
#       "saleFareTotal": "USD161.86",
#       "saleTaxTotal": "USD26.24",
#       "saleTotal": "USD188.10",
#       "passengers": {
#        "kind": "qpxexpress#passengerCounts",
#        "adultCount": 1
#       },
#       "tax": [
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "US_001",
#         "chargeType": "GOVERNMENT",
#         "code": "US",
#         "country": "US",
#         "salePrice": "USD12.14"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "AY_001",
#         "chargeType": "GOVERNMENT",
#         "code": "AY",
#         "country": "US",
#         "salePrice": "USD5.60"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "XF",
#         "chargeType": "GOVERNMENT",
#         "code": "XF",
#         "country": "US",
#         "salePrice": "USD4.50"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "ZP",
#         "chargeType": "GOVERNMENT",
#         "code": "ZP",
#         "country": "US",
#         "salePrice": "USD4.00"
#        }
#       ],
#       "fareCalculation": "WAS UA EWR Q18.60 143.26SAA21DHN USD 161.86 END ZP DCA XT 12.14US 4.00ZP 5.60AY 4.50XF DCA4.50",
#       "latestTicketingTime": "2015-07-07T23:59-04:00",
#       "ptc": "ADT"
#      }
#     ]
#    },
#    {
#     "kind": "qpxexpress#tripOption",
#     "saleTotal": "USD188.10",
#     "id": "3kErYB7Ip3MOHCjsjfYkkT001",
#     "slice": [
#      {
#       "kind": "qpxexpress#sliceInfo",
#       "duration": 65,
#       "segment": [
#        {
#         "kind": "qpxexpress#segmentInfo",
#         "duration": 65,
#         "flight": {
#          "carrier": "UA",
#          "number": "4711"
#         },
#         "id": "GaTGx04jTkmekc04",
#         "cabin": "COACH",
#         "bookingCode": "S",
#         "bookingCodeCount": 9,
#         "marriedSegmentGroup": "0",
#         "leg": [
#          {
#           "kind": "qpxexpress#legInfo",
#           "id": "L2P25zCbqav-bv5s",
#           "aircraft": "ERJ",
#           "arrivalTime": "2015-11-20T08:00-05:00",
#           "departureTime": "2015-11-20T06:55-05:00",
#           "origin": "DCA",
#           "destination": "EWR",
#           "originTerminal": "B",
#           "destinationTerminal": "A",
#           "duration": 65,
#           "operatingDisclosure": "OPERATED BY EXPRESSJET AIRLINES DBA UNITED EXPRESS",
#           "mileage": 198,
#           "secure": true
#          }
#         ]
#        }
#       ]
#      }
#     ],
#     "pricing": [
#      {
#       "kind": "qpxexpress#pricingInfo",
#       "fare": [
#        {
#         "kind": "qpxexpress#fareInfo",
#         "id": "AAUv/otBdsnI76pe6hMLjNTIJW163Hyn4StuCo4PteMBm9/",
#         "carrier": "UA",
#         "origin": "WAS",
#         "destination": "EWR",
#         "basisCode": "SAA21DHN"
#        }
#       ],
#       "segmentPricing": [
#        {
#         "kind": "qpxexpress#segmentPricing",
#         "fareId": "AAUv/otBdsnI76pe6hMLjNTIJW163Hyn4StuCo4PteMBm9/",
#         "segmentId": "GaTGx04jTkmekc04",
#         "freeBaggageOption": [
#          {
#           "kind": "qpxexpress#freeBaggageAllowance",
#           "bagDescriptor": [
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "UPTO50LB 23KG AND62LI 158LCM",
#             "count": 0,
#             "description": [
#              "Up to 50 lb/23 kg",
#              "Up to 62 li/158 lcm"
#             ],
#             "subcode": "0GO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "MUSICAL INSTRUMENTS",
#             "count": 0,
#             "subcode": "0F2"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "ARCHERY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Archery Equipment"
#             ],
#             "subcode": "0FO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "BOWLING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Bowling Equipment"
#             ],
#             "subcode": "0FS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "FISHING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Fishing Equipment"
#             ],
#             "subcode": "0D6"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "GOLF EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Golf Equipment"
#             ],
#             "subcode": "0DC"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "HOCKEY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Hockey Equipment"
#             ],
#             "subcode": "0F0"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKATEBOARD",
#             "count": 0,
#             "description": [
#              "Skateboard"
#             ],
#             "subcode": "0IS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Ski Equipment"
#             ],
#             "subcode": "0DD"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "WATER SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Water Ski Equipment"
#             ],
#             "subcode": "0G2"
#            }
#           ],
#           "pieces": 0
#          }
#         ]
#        }
#       ],
#       "baseFareTotal": "USD161.86",
#       "saleFareTotal": "USD161.86",
#       "saleTaxTotal": "USD26.24",
#       "saleTotal": "USD188.10",
#       "passengers": {
#        "kind": "qpxexpress#passengerCounts",
#        "adultCount": 1
#       },
#       "tax": [
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "US_001",
#         "chargeType": "GOVERNMENT",
#         "code": "US",
#         "country": "US",
#         "salePrice": "USD12.14"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "AY_001",
#         "chargeType": "GOVERNMENT",
#         "code": "AY",
#         "country": "US",
#         "salePrice": "USD5.60"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "XF",
#         "chargeType": "GOVERNMENT",
#         "code": "XF",
#         "country": "US",
#         "salePrice": "USD4.50"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "ZP",
#         "chargeType": "GOVERNMENT",
#         "code": "ZP",
#         "country": "US",
#         "salePrice": "USD4.00"
#        }
#       ],
#       "fareCalculation": "WAS UA EWR Q18.60 143.26SAA21DHN USD 161.86 END ZP DCA XT 12.14US 4.00ZP 5.60AY 4.50XF DCA4.50",
#       "latestTicketingTime": "2015-07-07T23:59-04:00",
#       "ptc": "ADT"
#      }
#     ]
#    },
#    {
#     "kind": "qpxexpress#tripOption",
#     "saleTotal": "USD200.10",
#     "id": "3kErYB7Ip3MOHCjsjfYkkT005",
#     "slice": [
#      {
#       "kind": "qpxexpress#sliceInfo",
#       "duration": 67,
#       "segment": [
#        {
#         "kind": "qpxexpress#segmentInfo",
#         "duration": 67,
#         "flight": {
#          "carrier": "UA",
#          "number": "4636"
#         },
#         "id": "GHN14yS3T6vzIrLt",
#         "cabin": "COACH",
#         "bookingCode": "V",
#         "bookingCodeCount": 8,
#         "marriedSegmentGroup": "0",
#         "leg": [
#          {
#           "kind": "qpxexpress#legInfo",
#           "id": "LVgXFXMNnWgCzHZn",
#           "aircraft": "ERJ",
#           "arrivalTime": "2015-11-20T12:07-05:00",
#           "departureTime": "2015-11-20T11:00-05:00",
#           "origin": "DCA",
#           "destination": "EWR",
#           "originTerminal": "B",
#           "destinationTerminal": "A",
#           "duration": 67,
#           "operatingDisclosure": "OPERATED BY EXPRESSJET AIRLINES DBA UNITED EXPRESS",
#           "onTimePerformance": 60,
#           "mileage": 198,
#           "secure": true
#          }
#         ]
#        }
#       ]
#      }
#     ],
#     "pricing": [
#      {
#       "kind": "qpxexpress#pricingInfo",
#       "fare": [
#        {
#         "kind": "qpxexpress#fareInfo",
#         "id": "ACPJtURojxAz4tNQ0wfA5ewPoTh5AHkjoGasYetBeZoPpHE",
#         "carrier": "UA",
#         "origin": "WAS",
#         "destination": "EWR",
#         "basisCode": "VAA14DHN"
#        }
#       ],
#       "segmentPricing": [
#        {
#         "kind": "qpxexpress#segmentPricing",
#         "fareId": "ACPJtURojxAz4tNQ0wfA5ewPoTh5AHkjoGasYetBeZoPpHE",
#         "segmentId": "GHN14yS3T6vzIrLt",
#         "freeBaggageOption": [
#          {
#           "kind": "qpxexpress#freeBaggageAllowance",
#           "bagDescriptor": [
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "UPTO50LB 23KG AND62LI 158LCM",
#             "count": 0,
#             "description": [
#              "Up to 50 lb/23 kg",
#              "Up to 62 li/158 lcm"
#             ],
#             "subcode": "0GO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "MUSICAL INSTRUMENTS",
#             "count": 0,
#             "subcode": "0F2"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "ARCHERY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Archery Equipment"
#             ],
#             "subcode": "0FO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "BOWLING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Bowling Equipment"
#             ],
#             "subcode": "0FS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "FISHING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Fishing Equipment"
#             ],
#             "subcode": "0D6"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "GOLF EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Golf Equipment"
#             ],
#             "subcode": "0DC"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "HOCKEY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Hockey Equipment"
#             ],
#             "subcode": "0F0"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKATEBOARD",
#             "count": 0,
#             "description": [
#              "Skateboard"
#             ],
#             "subcode": "0IS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Ski Equipment"
#             ],
#             "subcode": "0DD"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "WATER SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Water Ski Equipment"
#             ],
#             "subcode": "0G2"
#            }
#           ],
#           "pieces": 0
#          }
#         ]
#        }
#       ],
#       "baseFareTotal": "USD173.02",
#       "saleFareTotal": "USD173.02",
#       "saleTaxTotal": "USD27.08",
#       "saleTotal": "USD200.10",
#       "passengers": {
#        "kind": "qpxexpress#passengerCounts",
#        "adultCount": 1
#       },
#       "tax": [
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "US_001",
#         "chargeType": "GOVERNMENT",
#         "code": "US",
#         "country": "US",
#         "salePrice": "USD12.98"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "AY_001",
#         "chargeType": "GOVERNMENT",
#         "code": "AY",
#         "country": "US",
#         "salePrice": "USD5.60"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "XF",
#         "chargeType": "GOVERNMENT",
#         "code": "XF",
#         "country": "US",
#         "salePrice": "USD4.50"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "ZP",
#         "chargeType": "GOVERNMENT",
#         "code": "ZP",
#         "country": "US",
#         "salePrice": "USD4.00"
#        }
#       ],
#       "fareCalculation": "WAS UA EWR Q18.60 154.42VAA14DHN USD 173.02 END ZP DCA XT 12.98US 4.00ZP 5.60AY 4.50XF DCA4.50",
#       "latestTicketingTime": "2015-07-07T23:59-04:00",
#       "ptc": "ADT"
#      }
#     ]
#    },
#    {
#     "kind": "qpxexpress#tripOption",
#     "saleTotal": "USD200.10",
#     "id": "3kErYB7Ip3MOHCjsjfYkkT004",
#     "slice": [
#      {
#       "kind": "qpxexpress#sliceInfo",
#       "duration": 62,
#       "segment": [
#        {
#         "kind": "qpxexpress#segmentInfo",
#         "duration": 62,
#         "flight": {
#          "carrier": "UA",
#          "number": "4241"
#         },
#         "id": "GBIHIVJoJrXWCZa6",
#         "cabin": "COACH",
#         "bookingCode": "V",
#         "bookingCodeCount": 2,
#         "marriedSegmentGroup": "0",
#         "leg": [
#          {
#           "kind": "qpxexpress#legInfo",
#           "id": "LnwGxP76wP2Bfcg4",
#           "aircraft": "ERJ",
#           "arrivalTime": "2015-11-20T09:32-05:00",
#           "departureTime": "2015-11-20T08:30-05:00",
#           "origin": "DCA",
#           "destination": "EWR",
#           "originTerminal": "B",
#           "destinationTerminal": "A",
#           "duration": 62,
#           "operatingDisclosure": "OPERATED BY EXPRESSJET AIRLINES DBA UNITED EXPRESS",
#           "onTimePerformance": 90,
#           "mileage": 198,
#           "secure": true
#          }
#         ]
#        }
#       ]
#      }
#     ],
#     "pricing": [
#      {
#       "kind": "qpxexpress#pricingInfo",
#       "fare": [
#        {
#         "kind": "qpxexpress#fareInfo",
#         "id": "ACPJtURojxAz4tNQ0wfA5ewPoTh5AHkjoGasYetBeZoPpHE",
#         "carrier": "UA",
#         "origin": "WAS",
#         "destination": "EWR",
#         "basisCode": "VAA14DHN"
#        }
#       ],
#       "segmentPricing": [
#        {
#         "kind": "qpxexpress#segmentPricing",
#         "fareId": "ACPJtURojxAz4tNQ0wfA5ewPoTh5AHkjoGasYetBeZoPpHE",
#         "segmentId": "GBIHIVJoJrXWCZa6",
#         "freeBaggageOption": [
#          {
#           "kind": "qpxexpress#freeBaggageAllowance",
#           "bagDescriptor": [
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "UPTO50LB 23KG AND62LI 158LCM",
#             "count": 0,
#             "description": [
#              "Up to 50 lb/23 kg",
#              "Up to 62 li/158 lcm"
#             ],
#             "subcode": "0GO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "MUSICAL INSTRUMENTS",
#             "count": 0,
#             "subcode": "0F2"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "ARCHERY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Archery Equipment"
#             ],
#             "subcode": "0FO"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "BOWLING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Bowling Equipment"
#             ],
#             "subcode": "0FS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "FISHING EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Fishing Equipment"
#             ],
#             "subcode": "0D6"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "GOLF EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Golf Equipment"
#             ],
#             "subcode": "0DC"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "HOCKEY EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Hockey Equipment"
#             ],
#             "subcode": "0F0"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKATEBOARD",
#             "count": 0,
#             "description": [
#              "Skateboard"
#             ],
#             "subcode": "0IS"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Ski Equipment"
#             ],
#             "subcode": "0DD"
#            },
#            {
#             "kind": "qpxexpress#bagDescriptor",
#             "commercialName": "WATER SKI EQUIPMENT",
#             "count": 0,
#             "description": [
#              "Water Ski Equipment"
#             ],
#             "subcode": "0G2"
#            }
#           ],
#           "pieces": 0
#          }
#         ]
#        }
#       ],
#       "baseFareTotal": "USD173.02",
#       "saleFareTotal": "USD173.02",
#       "saleTaxTotal": "USD27.08",
#       "saleTotal": "USD200.10",
#       "passengers": {
#        "kind": "qpxexpress#passengerCounts",
#        "adultCount": 1
#       },
#       "tax": [
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "US_001",
#         "chargeType": "GOVERNMENT",
#         "code": "US",
#         "country": "US",
#         "salePrice": "USD12.98"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "AY_001",
#         "chargeType": "GOVERNMENT",
#         "code": "AY",
#         "country": "US",
#         "salePrice": "USD5.60"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "XF",
#         "chargeType": "GOVERNMENT",
#         "code": "XF",
#         "country": "US",
#         "salePrice": "USD4.50"
#        },
#        {
#         "kind": "qpxexpress#taxInfo",
#         "id": "ZP",
#         "chargeType": "GOVERNMENT",
#         "code": "ZP",
#         "country": "US",
#         "salePrice": "USD4.00"
#        }
#       ],
#       "fareCalculation": "WAS UA EWR Q18.60 154.42VAA14DHN USD 173.02 END ZP DCA XT 12.98US 4.00ZP 5.60AY 4.50XF DCA4.50",
#       "latestTicketingTime": "2015-07-07T23:59-04:00",
#       "ptc": "ADT"
#      }
#     ]
#    }
#   ]
#  }
# }
